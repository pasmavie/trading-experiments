# %%
from ib_insync import *
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from pandas.plotting import register_matplotlib_converters; register_matplotlib_converters()

import datetime
import pytz
PYTZ_AMS = pytz.timezone('Europe/Amsterdam')
PYTZ_NYC = pytz.timezone('America/New_York')

# %%
util.startLoop()

# %%
ib = IB()
ib.connect(
	'127.0.0.1',
	7496,# 4002, # TWS=7496, GTW=4001, # PAPER=7497
	clientId=3
)

ib.reqMarketDataType(1)

# %%
from equity import us_stocks, us_indices
from plots import plot_contracts_bars

# %%
plot_contracts_bars(ib, us_stocks)

# %% [markdown]
# ## Europe
#
# No access to hist data, although got it in TWS
#
# $BC @BVME fashion
#
# $ZAL @IBIS tech (consumer goods)
#
# $DHER @IBIS tech (food delivery)
#
# $UCG @BVME banking
#
# $G(enerali) @BVME banking
